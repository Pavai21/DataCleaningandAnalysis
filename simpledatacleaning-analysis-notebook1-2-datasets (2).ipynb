# %% [markdown]
# This project contains two datasets, the first covid dataset shows the performance of data cleaning and
# the second movie dataset shows data cleaning and simple analysis, where filtering out the budget greater than 2 crores and used different types of visualization.

# %%
import pandas as pd

# %% [markdown]
# **importing covid dataset(1)**

# %%
import pandas as pd
df = "../input/covid-dataset/Covid-19 Dataset.csv"
df1 = pd.read_csv(df)

# %%
df1
# Out:
#             Country        Date  Confirmed  Recovered  Deaths  Active Cases  \
# 0       Afghanistan  2020-01-22          0          0       0             0
# 1       Afghanistan  2020-01-23          0          0       0             0
# 2       Afghanistan  2020-01-24          0          0       0             0
# 3       Afghanistan  2020-01-25          0          0       0             0
# 4       Afghanistan  2020-01-26          0          0       0             0
# ...             ...         ...        ...        ...     ...           ...
# 101069     Zimbabwe  2021-06-21      42195      37200    1685          3310
# 101070     Zimbabwe  2021-06-22      42714      37288    1691          3735
# 101071     Zimbabwe  2021-06-23      43480      37477    1692          4311
# 101072     Zimbabwe  2021-06-24      44306      37524    1709          5073
# 101073     Zimbabwe  2021-06-25      45217      37604    1721          5892
#
# ...

# %%
df1.head(3)
# Out:
#        Country        Date  Confirmed  Recovered  Deaths  Active Cases  \
# 0  Afghanistan  2020-01-22          0          0       0             0
# 1  Afghanistan  2020-01-23          0          0       0             0
# 2  Afghanistan  2020-01-24          0          0       0             0
#
#    Death Rate(%)  Increase   FirstDays  day_xth  Population_1k     TenCase  \
# 0            0.0       0.0  2020-02-24        0          38928  2020-03-11
# 1            0.0       0.0  2020-02-24        0          38928  2020-03-11
# 2            0.0       0.0  2020-02-24        0          38928  2020-03-11
#
#    Cases/1000s
# 0          0.0
# 1          0.0
# 2          0.0

# %%
df1.shape
# Out:
# (101074, 13)

# %% [markdown]
# **Finding out the null values in dataset**

# %%
df1.isnull().sum()
# Out:
# Country             0
# Date                0
# Confirmed           0
# Recovered           0
# Deaths              0
# Active Cases        0
# Death Rate(%)       0
# Increase            6
# FirstDays           0
# day_xth             0
# Population_1k       0
# TenCase          3647
# Cases/1000s         0
# dtype: int64

# %%
df1.TenCase.isnull().sum()
# Out:
# 3647

# %% [markdown]
# **Deleting the 'Tencase' column which has null values**

# %%
del df1['TenCase']

# %% [markdown]
# **Checking if Tencase column is deleted**

# %%
df1.tail(2)
# Out:
#          Country        Date  Confirmed  Recovered  Deaths  Active Cases  \
# 101072  Zimbabwe  2021-06-24      44306      37524    1709          5073
# 101073  Zimbabwe  2021-06-25      45217      37604    1721          5892
#
#         Death Rate(%)  Increase   FirstDays  day_xth  Population_1k  \
# 101072       3.857265     826.0  2020-03-20      461          14862
# 101073       3.806091     911.0  2020-03-20      462          14862
#
#         Cases/1000s
# 101072     2.981160
# 101073     3.042457

# %% [markdown]
# **Importing Movie dataset(2)**

# %%
Movie_data = "../input/movies-data-1916-2016/MovieAssignmentData.csv"
df_data = pd.read_csv(Movie_data)
df_data
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df_data.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df_data.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
df_data.head(3)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
# 2  Color      Sam Mendes                   602.0     148.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# ...

# %% [markdown]
# **Dropping nan values in dataset**

# %%
df_data.dropna(how='all')
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# **filling zero in the place of nan **

# %%
df_data.fillna(0, inplace = True)

# %%
df_data
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4         0        Doug Walker                     0.0       0.0
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                  0                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# **Just visualising whether null values are left**

# %%
import seaborn as sns

# %% [markdown]
# **Shows no nan in dataset**

# %%
sns.heatmap(df_data.isnull())
# Out:
# <AxesSubplot:>

# %%
df_data.isnull().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %% [markdown]
# **Finding out the duplicates in dataset**

# %%
df_data.duplicated().sum()
# Out:
# 45

# %%
duplicate = df_data[df_data.duplicated()]

# %%
duplicate
# Out:
#                  color         director_name  num_critic_for_reviews  \
# 137              Color           David Yates                   248.0
# 187              Color           Bill Condon                   322.0
# 204              Color          Hideaki Anno                     1.0
# 303              Color            Joe Wright                   256.0
# 389              Color            Josh Trank                   369.0
# 395              Color             Rob Cohen                   187.0
# 590              Color          Brett Ratner                   245.0
# 656              Color        Paul Verhoeven                   196.0
# 794              Color           Joss Whedon                   703.0
# 1220             Color   Angelina Jolie Pitt                   322.0
# 1305             Color         Paul McGuigan                   159.0
# 1449             Color         Albert Hughes                   208.0
# 2169             Color         Paul McGuigan                    98.0
# ...

# %% [markdown]
# **Dropping the duplicate values**

# %%
drop_duplicate = df_data.drop_duplicates()

# %%
drop_duplicate
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4         0        Doug Walker                     0.0       0.0
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                  0                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# **Filtering the necessary columns for analyse**

# %%
Filtered_Data = drop_duplicate.filter(['country','director_name','title_year','genres','budget','imdb_score'])

# %%
Filtered_Data
# Out:
#      country      director_name  title_year                           genres  \
# 0        USA      James Cameron      2009.0  Action|Adventure|Fantasy|Sci-Fi
# 1        USA     Gore Verbinski      2007.0         Action|Adventure|Fantasy
# 2         UK         Sam Mendes      2015.0        Action|Adventure|Thriller
# 3        USA  Christopher Nolan      2012.0                  Action|Thriller
# 4          0        Doug Walker         0.0                      Documentary
# ...      ...                ...         ...                              ...
# 5038  Canada        Scott Smith      2013.0                     Comedy|Drama
# 5039     USA                  0         0.0     Crime|Drama|Mystery|Thriller
# 5040     USA   Benjamin Roberds      2013.0            Drama|Horror|Thriller
# 5041     USA        Daniel Hsia      2012.0             Comedy|Drama|Romance
# 5042     USA           Jon Gunn      2004.0                      Documentary
#
#            budget  imdb_score
# ...

# %%
df2 = Filtered_Data.sort_values(by=['title_year','budget','imdb_score'],ascending = False)

# %%
df2
# Out:
#      country  director_name  title_year                            genres  \
# 27       USA  Anthony Russo      2016.0           Action|Adventure|Sci-Fi
# 10       USA    Zack Snyder      2016.0           Action|Adventure|Sci-Fi
# 57       USA     Justin Lin      2016.0  Action|Adventure|Sci-Fi|Thriller
# 63       USA    David Yates      2016.0    Action|Adventure|Drama|Romance
# 65       USA   Bryan Singer      2016.0           Action|Adventure|Sci-Fi
# ...      ...            ...         ...                               ...
# 4634     USA              0         0.0                            Comedy
# 1404     USA              0         0.0               Action|Comedy|Crime
# 4113     USA              0         0.0            Horror|Sci-Fi|Thriller
# 2191     USA              0         0.0                            Comedy
# 3303     USA              0         0.0                     Drama|Romance
#
#            budget  imdb_score
# 27    250000000.0         8.2
# ...

# %%
df2['genres'].value_counts()
# Out:
# Drama                                            235
# Comedy                                           205
# Comedy|Drama                                     189
# Comedy|Drama|Romance                             187
# Comedy|Romance                                   158
#                                                 ...
# Biography|Comedy|Crime|Drama|Romance|Thriller      1
# Crime|Drama|Mystery|Thriller|Western               1
# Action|Horror|Mystery|Sci-Fi|Thriller              1
# Crime|Drama|History|Mystery|Thriller               1
# Adventure|Comedy|Family|Music|Romance              1
# Name: genres, Length: 914, dtype: int64

# %% [markdown]
# **Getting the budget value greater than 200000000**

# %%
df3 = df2[(df2['budget']>200000000)]

# %%
df4 = df3.head(20)

# %%
df4
# Out:
#           country      director_name  title_year  \
# 27            USA      Anthony Russo      2016.0
# 10            USA        Zack Snyder      2016.0
# 8             USA        Joss Whedon      2015.0
# 2              UK         Sam Mendes      2015.0
# 20    New Zealand      Peter Jackson      2014.0
# 37            USA        Michael Bay      2014.0
# 23            USA      Peter Jackson      2013.0
# 15            USA        Zack Snyder      2013.0
# 14            USA     Gore Verbinski      2013.0
# 38            USA          Sam Raimi      2013.0
# 4778          USA          Sam Raimi      2013.0
# 5             USA     Andrew Stanton      2012.0
# 3             USA  Christopher Nolan      2012.0
# 21            USA          Marc Webb      2012.0
# 19            USA   Barry Sonnenfeld      2012.0
# 17            USA        Joss Whedon      2012.0
# 28            USA         Peter Berg      2012.0
# 18            USA       Rob Marshall      2011.0
# ...

# %% [markdown]
# **Visualising Country vs Budget using matplotlib**

# %%
import matplotlib.pyplot as plt

# %%
x = df4['country']
y = df4['budget']

# %%
plt.figure(figsize=(10,9))
plt.bar(x,y)
plt.title("Country vs Budget",fontsize =20)
plt.xlabel("Country", fontsize = 12)
plt.ylabel("Budget", fontsize = 12)
# Out:
# Text(0, 0.5, 'Budget')

# %% [markdown]
# **By using seaborn, shows how the imdb_score distributed**

# %%
import seaborn as sns

# %%
sns.distplot(df4['imdb_score'],bins=5)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='imdb_score', ylabel='Density'>

# %% [markdown]
# **Using plotly visualization,Pie-chart made between imdb_scores and genres**

# %%
import plotly
import plotly.express as px

# %%
px.pie(df4,values='imdb_score',names='genres',labels='genres',title='Genres vs Imdb_Score')
# Out:
# <div>                            <div id="8da4da32-3f30-4f16-aa1a-a15127ff4d74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8da4da32-3f30-4f16-aa1a-a15127ff4d74")) {                    Plotly.newPlot(                        "8da4da32-3f30-4f16-aa1a-a15127ff4d74",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "genres=%{label}<br>imdb_score=%{value}<extra></extra>", "labels": ["Action|Adventure|Sci-Fi", "Action|Adventure|Sci-Fi", "Action|Adventure|Sci-Fi", "Action|Adventure|Thriller", "Adventure|Fantasy", "Action|Adventure|Sci-Fi", "Adventure|Fantasy", "Action|Adventure|Fantasy|Sci-Fi", "Action|Adventure|Western", "Adventure|Family|Fantasy", "Adventure|Family|Fantasy", "Action|Adventure|Sci-Fi", "Action|Th
# ...
